# %% [markdown]
# * [1. Problem Statement](#0)
# * [2. Getting Started - Load Libraries and Dataset](#1)
#     * [2.1. Load Libraries](#1.1)
#     * [2.2. Load Dataset](#1.2)

# %% [markdown]
# <a id='0'></a>
# # 1. Problem Statement

# %% [markdown]
# Content:
#     Stock
#     Many stocks/Indices
#     Crypto
#     FX
#     Finacial
#     Real Time Data
#     List of tickers available

# %%
import numpy as np
import pandas as pd
# !pip install fxcmpy

# %%
Content:
    Crypto
    FX
    High Frequency Data
    List of tickers available

# %%
# 28ff5032b04279ad8ec9b4a52733e5451faa0cd7
# 28ff5032b04279ad8ec9b4a52733e5451faa0cd7
import fxcmpy 
import datetime as dt
token = '28ff5032b04279ad8ec9b4a52733e5451faa0cd7'
con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error')
print(con.get_instruments())
start = dt.datetime(2019, 12, 1)
end = dt.datetime(2020, 1, 4)
data = con.get_candles('SPX500', period='D1', start= start, end= end)
data
# Out:
# ['EUR/USD', 'USD/JPY', 'GBP/USD', 'USD/CHF', 'EUR/CHF', 'AUD/USD', 'USD/CAD', 'NZD/USD', 'EUR/GBP', 'EUR/JPY', 'GBP/JPY', 'CHF/JPY', 'GBP/CHF', 'EUR/AUD', 'EUR/CAD', 'AUD/CAD', 'AUD/JPY', 'CAD/JPY', 'NZD/JPY', 'GBP/CAD', 'GBP/NZD', 'GBP/AUD', 'AUD/NZD', 'USD/SEK', 'EUR/SEK', 'EUR/NOK', 'USD/NOK', 'USD/MXN', 'AUD/CHF', 'EUR/NZD', 'USD/ZAR', 'USD/HKD', 'ZAR/JPY', 'USD/TRY', 'EUR/TRY', 'NZD/CHF', 'CAD/CHF', 'NZD/CAD', 'TRY/JPY', 'AUS200', 'ESP35', 'FRA40', 'GER30', 'HKG33', 'JPN225', 'NAS100', 'SPX500', 'UK100', 'US30', 'Copper', 'CHN50', 'EUSTX50', 'USDOLLAR', 'US2000', 'USOil', 'UKOil', 'SOYF', 'NGAS', 'WHEATF', 'CORNF', 'Bund', 'XAU/USD', 'XAG/USD', 'EMBasket', 'JPYBasket', 'BTC/USD', 'BCH/USD', 'ETH/USD', 'LTC/USD', 'XRP/USD', 'CryptoMajor', 'USEquities']
#                      bidopen  bidclose  bidhigh  ...  askhigh   asklow  tickqty
# date                                             ...
# 2019-12-02 22:00:00  3142.72   3112.74  3157.60  ...  3158.04  3110.48   413027
# 2019-12-03 22:00:00  3112.74   3092.14  3121.84  ...  3122.22  3070.16   533835
# 2019-12-04 22:00:00  3092.14   3110.64  3119.46  ...  3120.10  3082.34   419987
# 2019-12-05 22:00:00  3110.64   3116.80  3123.98  ...  3124.50  3103.14   388835
# 2019-12-06 22:00:00  3116.80   3145.56  3150.06  ...  3150.50  3116.88   277541
# 2019-12-09 22:00:00  3145.56   3131.86  3148.54  ...  3149.10  3130.82   254212
# 2019-12-10 22:00:00  3131.86   3136.52  3142.58  ...  3143.10  3116.34   396947
# 2019-12-11 22:00:00  3136.52   3143.42  3144.16  ...  3144.70  3129.88   307671
# 2019-12-12 22:00:00  3143.42   3168.76  3176.56  ...  3177.10  3137.28   468625
# 2019-12-13 22:00:00  3168.76   3170.70  3184.00  ...  3184.50  3156.18   534754
# 2019-12-16 22:00:00  3170.70   3192.58  3197.94  ...  3198.32  3173.46   254524
# 2019-12-17 22:00:00  3192.58   3189.56  3199.04  ...  3199.48  3187.88   262394
# 2019-12-18 22:00:00  3189.56   3195.96  3199.56  ...  3200.10  3189.02   188759
# 2019-12-19 22:00:00  3195.96   3209.10  3210.64  ...  3211.30  3191.62   181732
# 2019-12-20 22:00:00  3209.10   3222.72  3227.02  ...  3227.50  3205.96   215718
# 2019-12-23 22:00:00  3222.72   3225.94  3232.36  ...  3232.96  3222.98   160541
# 2019-12-24 22:00:00  3225.94   3224.70  3229.68  ...  3230.30  3221.66    92574
# 2019-12-26 22:00:00  3224.70   3240.74  3243.42  ...  3243.90  3228.44    84454
# 2019-12-28 03:00:00  3240.74   3236.02  3252.76  ...  3253.30  3234.72   272165
# 2019-12-30 22:00:00  3237.30   3221.80  3243.32  ...  3243.70  3216.68   294069
# 2019-12-31 22:00:00  3221.80   3219.28  3227.12  ...  3227.50  3212.36   483326
# 2020-01-02 22:00:00  3219.28   3260.56  3261.08  ...  3261.46  3219.64   249106
# 2020-01-03 22:00:00  3237.34   3234.80  3237.94  ...  3238.50  3233.92    11336
# 2020-01-04 03:00:00  3260.56   3238.20  3262.74  ...  3263.30  3207.02   487113
#
# [24 rows x 9 columns]

# %%
# https://fxcmpy.tpq.io/index.html
! pip install pyti
# Out:
# Collecting pyti
#   Downloading https://files.pythonhosted.org/packages/0f/9a/913e5bc3c3e812b490338fc9096b608cf0e19d1c3cd5b1c2b58b77b69b85/pyti-0.2.2-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pyti) (1.17.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pyti) (0.25.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->pyti) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->pyti) (2.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->pyti) (1.12.0)
# Installing collected packages: pyti
# Successfully installed pyti-0.2.2

# %%
from pyti.bollinger_bands import upper_bollinger_band as
