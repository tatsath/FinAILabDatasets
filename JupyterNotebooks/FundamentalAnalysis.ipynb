# %% [markdown]
# ### Import Libraries

# %%
import FundamentalAnalysis as fa
import financedatabase as fd
import pandas as pd
ticker = "TSLA"
api_key = "7b95034d43c6ccb530b841102ac7bc8f"

# %% [markdown]
# The below command lists all options available to be queried

# %%
# Options: 'cryptocurrencies', 'currencies', 'equities', 'etfs' or 'funds'
options = fd.show_options('cryptocurrencies', equities_selection=None, country=None, sector=None, industry=None)
options = pd.DataFrame(options)
options
# Out:
#         0
# 0    AAVE
# 1    ABBC
# 2     ACH
# 3     ACT
# 4     ADA
# ..    ...
# 346   ZIL
# 347   ZNN
# 348   ZRX
# 349   ZVC
# 350   ZYN
#
# [351 rows x 1 columns]

# %%
# Show the available companies
companies = fa.available_companies(api_key)
companies.sort_values('symbol')
# Out:
#                                                         name   price  \
# symbol
# 000001.SZ                             Ping An Bank Co., Ltd.   16.82
# 000002.SZ                              China Vanke Co., Ltd.   19.12
# 000004.SZ  Shenzhen GuoHua Network Security Technology Co...   19.60
# 000005.SZ                      Shenzhen Fountain Corporation    2.29
# 000006.SZ                   Shenzhen Zhenye (Group) Co.,Ltd.    4.38
# ...                                                      ...     ...
# ZYT.L                                           Zytronic plc  170.00
# ZYXI                                             Zynex, Inc.   10.34
# ZZLL                       ZZLL Information Technology, Inc.    0.23
# ZZZ.TO                    Sleep Country Canada Holdings Inc.   37.73
# ZZZD.TO                   BMO Tactical Dividend ETF Fund ETF   28.27
#
#                         exchange exchangeShortName   type
# symbol
# 000001.SZ               Shenzhen               SHZ  stock
# 000002.SZ               Shenzhen               SHZ  stock
# 000004.SZ               Shenzhen               SHZ  stock
# 000005.SZ               Shenzhen               SHZ  stock
# 000006.SZ               Shenzhen               SHZ  stock
# ...                          ...               ...    ...
# ZYT.L                        LSE               LSE  stock
# ZYXI       Nasdaq Capital Market            NASDAQ  stock
# ZZLL                   Other OTC       MUTUAL_FUND  stock
# ZZZ.TO                   Toronto               TSX  stock
# ZZZD.TO                  Toronto               TSX    etf
#
# [33459 rows x 5 columns]

# %%
# Supported exchanges
companies.exchange.unique()
# Out:
# array(['New York Stock Exchange Arca', 'Nasdaq Global Select',
#        'New York Stock Exchange', 'Nasdaq Global Market',
#        'Nasdaq Capital Market', 'BATS Exchange', 'BATS',
#        'NASDAQ Global Market', 'OTC', 'Other OTC', 'Paris', 'Amsterdam',
#        'Brussels', 'Lisbon', 'Toronto', 'YHD', 'EURONEXT', 'Swiss',
#        'AMEX', 'MCX', 'XETRA', 'NSE', 'LSE', 'SIX', 'HKSE', 'OSE',
#        'NASDAQ', 'Sao Paolo', 'TSXV', 'Frankfurt', 'HKG', 'NCM', 'MCE',
#        'ASE', 'OSL', 'Oslo', 'FGI', 'Irish', 'Canadian Sec', 'NZSE',
#        'Nasdaq', 'Jakarta', 'Vienna', 'Santiago', 'Shenzhen', 'Shanghai',
#        'Hamburg', 'Copenhagen', 'Helsinki', 'Athens', 'Milan', 'Tokyo',
#        'KSE', 'KOSDAQ', 'Stockholm', 'Istanbul', 'Taiwan', 'Mexico',
#        'Johannesburg', 'SAT', 'São Paulo', 'Tel Aviv', 'Warsaw',
#        'Thailand', 'IOB', 'Qatar', 'Kuala Lumpur', 'Prague', 'SES',
#        'Berlin', 'Taipei Exchange', 'Saudi', 'NasdaqGM', 'NasdaqGS',
#        'Iceland', 'NYSE American', 'NASDAQ Capital Market'], dtype=object)

# %%
# Company Profile
profile = fa.profile(ticker, api_key)
profile
# Out:
#                                                                    0
# symbol                                                          TSLA
# price                                                        1026.96
# beta                                                        2.037922
# volAvg                                                      27359982
# mktCap                                                 1031334789120
# lastDiv                                                          0.0
# range                                                 539.49-1243.49
# changes                                                    -37.73999
# companyName                                              Tesla, Inc.
# currency                                                         USD
# cik                                                       0001318605
# isin                                                    US88160R1014
# cusip                                                      88160R101
# exchange                                        Nasdaq Global Select
# exchangeShortName                                             NASDAQ
# industry                                          Auto Manufacturers
# website                                        https://www.tesla.com
# description        Tesla, Inc. designs, develops, manufactures, l...
# ceo                                                    Mr. Elon Musk
# sector                                             Consumer Cyclical
# country                                                           US
# fullTimeEmployees                                              70757
# phone                                                    16506815000
# address                                           3500 Deer Creek Rd
# city                                                       Palo Alto
# state                                                     CALIFORNIA
# zip                                                            78725
# dcfDiff                                                      12772.3
# dcf                                                          1044.07
# image              https://financialmodelingprep.com/image-stock/...
# ipoDate                                                   2010-06-29
# defaultImage                                                   False
# isEtf                                                          False
# isActivelyTrading                                               True
# isAdr                                                          False
# isFund                                                         False

# %%
# Latest Quote
quotes = fa.quote(ticker, api_key)
quotes

# %%
# Analysts Recommendation/Ratings
ratings = fa.rating(ticker, api_key)
ratings
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pk/ntxqk62j0_jb9d_f4plbpzv80000gn/T/ipykernel_24051/1997791733.py in <module>
#       1 # Analysts Recommendation/Ratings
# ----> 2 ratings = fa.rating('ADA', api_key)
#       3 ratings
#
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/FundamentalAnalysis/details.py in rating(ticker, api_key)
#     189         del value['symbol']
#     190
# --> 191     data_formatted = pd.DataFrame(data_json).set_index('date')
#     192
#     193     return data_formatted
#
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
# Obtain DCFs over time
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
dcf_quarterly = fa.discounted_cash_flow(ticker, api_key, period="quarter")

# %%
dcf_annually

# %%
dcf_quarterly

# %%
# Balance Sheet statements
balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")
balance_sheet_quarterly = fa.balance_sheet_statement(ticker, api_key, period="quarter")

# %%
balance_sheet_annually

# %%
# Income Statements
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")
income_statement_quarterly = fa.income_statement(ticker, api_key, period="quarter")

# %%
income_statement_quarterly

# %%
# Cash Flow Statements
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")
cash_flow_statement_quarterly = fa.cash_flow_statement(ticker, api_key, period="quarter")

# %%
cash_flow_statement_annually

# %%
# Key Metrics
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_quarterly = fa.key_metrics(ticker, api_key, period="quarter")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/FundamentalAnalysis/ratios.py in key_metrics(ticker, api_key, period, TTM, limit)
#      37     try:
# ---> 38         response = urlopen(URL)
#      39         data = json.loads(response.read().decode("utf-8"))
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 403:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/pk/ntxqk62j0_jb9d_f4plbpzv80000gn/T/ipykernel_24051/492065257.py in <module>
#       1 # Key Metrics
#       2 key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
# ----> 3 key_metrics_quarterly = fa.key_metrics(ticker, api_key, period="quarter")
#
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/FundamentalAnalysis/ratios.py in key_metrics(ticker, api_key, period, TTM, limit)
#      39         data = json.loads(response.read().decode("utf-8"))
#      40     except HTTPError:
# ---> 41         raise ValueError("This endpoint is only for premium members. Please visit the subscription page to upgrade the "
#      42                          "plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing")
#      43
#
# ValueError: This endpoint is only for premium members. Please visit the subscription page to upgrade the plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing

# %%
key_metrics_quarterly

# %%
# Large set of in-depth ratios
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")
financial_ratios_quarterly = fa.financial_ratios(ticker, api_key, period="quarter")
financial_ratios_quarterly
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/FundamentalAnalysis/ratios.py in financial_ratios(ticker, api_key, period, TTM, limit)
#      95     try:
# ---> 96         response = urlopen(URL)
#      97         data = json.loads(response.read().decode("utf-8"))
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 403:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/pk/ntxqk62j0_jb9d_f4plbpzv80000gn/T/ipykernel_24051/2142551693.py in <module>
#       1 # Large set of in-depth ratios
#       2 financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")
# ----> 3 financial_ratios_quarterly = fa.financial_ratios(ticker, api_key, period="quarter")
#       4 financial_ratios_quarterly
#
# ~/Desktop/FinAILabDatasets/venv/lib/python3.8/site-packages/FundamentalAnalysis/ratios.py in financial_ratios(ticker, api_key, period, TTM, limit)
#      97         data = json.loads(response.read().decode("utf-8"))
#      98     except HTTPError:
# ---> 99         raise ValueError("This endpoint is only for premium members. Please visit the subscription page to upgrade the "
#     100                          "plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing")
#     101
#
# ValueError: This endpoint is only for premium members. Please visit the subscription page to upgrade the plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing

# %%
# Growth of the company
growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")
growth_quarterly = fa.financial_statement_growth(ticker, api_key, period="quarter")
growth_quarterly

# %%
# General stock data
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")

# Detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2020-01-01")
stock_data_detailed
# Out:
#                  open       high        low      close   adjClose      volume  \
# 2019-12-31       81.0  84.258003     80.416     83.666     83.666  51428500.0
# 2019-12-30  85.758003  85.800003  81.851997  82.940002  82.940002  62932000.0
# 2019-12-27       87.0  87.061996     85.222  86.075996  86.075996  49728500.0
# 2019-12-26  85.582001  86.695999  85.269997  86.188004  86.188004  53169500.0
# 2019-12-24  83.671997  85.094002  82.538002  85.050003  85.050003  40273500.0
# ...               ...        ...        ...        ...        ...         ...
# 2010-07-06        4.0        4.0      3.166      3.222      3.222  34334500.0
# 2010-07-02        4.6       4.62      3.742       3.84       3.84  25699000.0
# 2010-07-01        5.0      5.184      4.054      4.392      4.392  41094000.0
# 2010-06-30      5.158      6.084       4.66      4.766      4.766  85935500.0
# 2010-06-29        3.8        5.0      3.508      4.778      4.778  93831500.0
#
#            unadjustedVolume   change changePercent      vwap            label  \
# 2019-12-31       51428500.0    2.666         3.291     82.78  December 31, 19
# 2019-12-30       62932000.0   -2.818        -3.286  83.53067  December 30, 19
# 2019-12-27       49728500.0   -0.924        -1.062     86.12  December 27, 19
# 2019-12-26       53169500.0    0.606         0.708  86.05133  December 26, 19
# 2019-12-24       40273500.0  1.37801         1.647  84.22734  December 24, 19
# ...                     ...      ...           ...       ...              ...
# 2010-07-06       34334500.0   -0.778        -19.45   3.46267      July 06, 10
# 2010-07-02       25699000.0    -0.76       -16.522   4.06733      July 02, 10
# 2010-07-01       41094000.0   -0.608        -12.16   4.54333      July 01, 10
# 2010-06-30       85935500.0   -0.392          -7.6      5.17      June 30, 10
# 2010-06-29       93831500.0    0.978        25.737   4.42867      June 29, 10
#
#            changeOverTime
# 2019-12-31        0.03291
# 2019-12-30       -0.03286
# 2019-12-27       -0.01062
# 2019-12-26        0.00708
# 2019-12-24        0.01647
# ...                   ...
# 2010-07-06        -0.1945
# 2010-07-02       -0.16522
# 2010-07-01        -0.1216
# 2010-06-30         -0.076
# 2010-06-29        0.25737
#
# [2394 rows x 12 columns]
